# %%
#Importing all the useful libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing dataset
data = pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## 1 Checking First 5 rows of the dataset

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ## 2 Checking last 5 rows of the datasets

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
# ...

# %% [markdown]
# ## 3 Checking random rows of the datasets

# %%
data.sample(5)
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 249  785-13-7708      B  Mandalay        Normal    Male
# 878  448-61-3783      A    Yangon        Normal  Female
# 785  404-91-5964      A    Yangon        Normal    Male
# 487  795-49-7276      A    Yangon        Normal    Male
# 851  409-33-9708      A    Yangon        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 249      Food and beverages       73.06         7  25.571  536.991 2019-01-14
# 878  Electronic accessories       90.02         8  36.008  756.168 2019-03-21
# 785  Electronic accessories       74.58         7  26.103  548.163 2019-02-04
# 487     Fashion accessories       37.15         4   7.430  156.030 2019-03-23
# 851     Fashion accessories       98.48         2   9.848  206.808 2019-02-19
#
#       Time      Payment    cogs  gross margin percentage  gross income  Rating
# 249  19:06  Credit card  511.42                 4.761905        25.571     4.2
# ...

# %% [markdown]
# ## 4 checking shape of the dataset, As in number of rows and number of columns

# %%
data.shape
# Out:
# (1000, 17)

# %%
print("Number of Columns",data.shape[0])
print("Number of Rows",data.shape[1])
# Out:
# Number of Columns 1000
# Number of Rows 17

# %% [markdown]
# ## 5 Checking null values in the datasets

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ## 6 Checking the detailed info of our datasets

# %%
#Number of rows and columns, datatypes and memory requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# ## 7 checking the statistics of our datasets

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        cogs  gross margin percentage  \
# count                        1000  1000.00000             1.000000e+03
# mean   2019-02-14 00:05:45.600000   307.58738             4.761905e+00
# min           2019-01-01 00:00:00    10.17000             4.761905e+00
# 25%           2019-01-24 00:00:00   118.49750             4.761905e+00
# 50%           2019-02-13 00:00:00   241.76000             4.761905e+00
# ...

# %% [markdown]
# # Univariate Analysis

# %%
#Categorical and Numberical Columns
cat = []
num = []
for column in data.columns:
    if data [column].nunique() >10:
         num.append(column)
    else:
         cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# ## 1 Aggregate Sales among Branches(Categorical Columns)

# %%
sns.countplot(x=data['Branch'], data=data)
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
data["Branch"].value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
data["Branch"].nunique()
# Out:
# 3

# %%
data["Branch"].value_counts().plot(kind="pie", autopct="%1.0f%%")
# Out:
# <Axes: ylabel='count'>

# %%
data["Branch"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Branch'>

# %% [markdown]
# ## 2 To check most common payment methods used by the customers

# %%
data["Payment"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Payment'>

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# ## 3 Distribution of Customer Ratings

# %%
sns.displot(data["Rating"])
# Out:
# C:\Users\akans\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#to check the skewness of data
data["Rating"].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# ## 4 Distribution of costs of goods sold

# %%
sns.distplot(data["cogs"])
# Out:
# C:\Users\akans\AppData\Local\Temp\ipykernel_304\3875859950.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["cogs"])
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
#Right skewed
data["cogs"].skew()
# Out:
# 0.8925698049581418

# %% [markdown]
# ## 5 Boxplot

# %%
sns.boxplot(x="cogs", data=data)
plt.show()

# %% [markdown]
# # Bivariate Analysis and Multivariate Analysis

# %% [markdown]
# ## 1 To check if the cost of goods sold affect the ratings that the customers provide? (Numerical columns)

# %%
sns.scatterplot(data["cogs"])
# Out:
# <Axes: ylabel='cogs'>

# %% [markdown]
# ## 2 To check if the gross income affect the ratings that customer provide.(Numerical columns)

# %%
sns.scatterplot(data["gross income"], data["Rating"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.scatterplot(data["gross income"], data["Rating"])
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.scatterplot(data=data,x ="gross income", y="Rating")
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# ## 3 To check the most profitable branch as per Gross Income.(Numerical and Categorical Column)

# %%
sns.barplot(x="Branch", y="gross income", data=data)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x="Branch", y="gross income", data=data, hue=data["City"])
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# ## 4 to check the relationship between gender and gross income (Numerical and categorical columns )

# %%
sns.boxplot(x="Gender", y="gross income", data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x="Gender", y="gross income", data=data, hue=data["Customer type"])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# ## 5 To find the Product line that generates the most income.

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(data=data, x="Product line", y="gross income")
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 6 Find the highest Unit Price in the product line.(Numerical and Categorical column)

# %%
sns.barplot(data=data, x="Product line", y="Unit price")
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 7 To check the different payment method used by customers citywise(Categorical and Categorical columns)

# %%
pd.crosstab(data["City"], data["Payment"])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(data["City"], data["Payment"]))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %% [markdown]
# ## 8 Which Product line is purchased in the highest quantity.

# %%
(data.groupby("Product line").sum()["Quantity"]).plot(kind="bar")
plt.show()

# %%
(data.groupby("Product line").sum()["Quantity"]).plot(kind="bar")
plt.ylabel('Total Quantity')
plt.title('Total Quantity Sold by Product Line')
plt.show()

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## 9 Display Daily Sales by the Day of the Week.

# %%
data["Date"]=pd.to_datetime(data["Date"])

# %%
data["Date"].dt.dayofweek
# Out:
# 0      5
# 1      4
# 2      6
# 3      6
# 4      4
#       ..
# 995    1
# 996    5
# 997    5
# 998    4
# 999    0
# Name: Date, Length: 1000, dtype: int32

# %%
dw_mapping = {0:"Monday",
             1:"Tuesday",
             2:"Wednesday",
             3:"Thursday",
             4:"Friday",
             5:"Saturday",
             6:"Sunday"}

# %%
data["Date"].dt.dayofweek.map(dw_mapping)
# Out:
# 0      Saturday
# 1        Friday
# 2        Sunday
# 3        Sunday
# 4        Friday
#          ...
# 995     Tuesday
# 996    Saturday
# 997    Saturday
# 998      Friday
# 999      Monday
# Name: Date, Length: 1000, dtype: object

# %%
data["Day_of_week"]=data["Date"].dt.dayofweek.map(dw_mapping)

# %%
data.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating Day_of_week
# 0                 4.761905       26.1415     9.1    Saturday

# %%
data["Day_of_week"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Day_of_week'>

# %% [markdown]
# ## 10 To check Highest Months for sales.

# %%
data["Month"]=data["Date"].dt.month.map(month_mapping)

# %%
month_mapping = {1:"January",
             2:"Febuary",
             3:"March",
             4:"April",
             5:"May",
             6:"June",
             7:"July",
             8:"August",
             9:"September",
             10:"October",
             11:"November",
             12:"December"}

# %%
data.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating Day_of_week    Month
# 0                 4.761905       26.1415     9.1    Saturday  January

# %%
data["Month"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Month'>

# %%
 data["Month"].nunique()
# Out:
# 3
